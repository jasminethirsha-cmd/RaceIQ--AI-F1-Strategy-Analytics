# %%
import pandas as pd

races = pd.read_csv("f1_races_2000_2026.csv")

print(races.head())
# Out:
#    season  round              race_name   circuit_id  \
# 0    2000      1  Australian Grand Prix  albert_park
# 1    2000      2   Brazilian Grand Prix   interlagos
# 2    2000      3  San Marino Grand Prix        imola
# 3    2000      4     British Grand Prix  silverstone
# 4    2000      5     Spanish Grand Prix    catalunya
#
#                      circuit_name    country     locality        date  \
# 0  Albert Park Grand Prix Circuit  Australia    Melbourne  2000-03-12
# 1      Autódromo José Carlos Pace     Brazil    São Paulo  2000-03-26
# 2   Autodromo Enzo e Dino Ferrari      Italy        Imola  2000-04-09
# 3             Silverstone Circuit         UK  Silverstone  2000-04-23
# 4  Circuit de Barcelona-Catalunya      Spain    Barcelona  2000-05-07
#
#                                             race_url
# 0  https://en.wikipedia.org/wiki/2000_Australian_...
# 1  https://en.wikipedia.org/wiki/2000_Brazilian_G...
# 2  https://en.wikipedia.org/wiki/2000_San_Marino_...
# ...

# %%
pd.read_csv("f1_races_2000_2026.csv")
# Out:
#      season  round               race_name   circuit_id  \
# 0      2000      1   Australian Grand Prix  albert_park
# 1      2000      2    Brazilian Grand Prix   interlagos
# 2      2000      3   San Marino Grand Prix        imola
# 3      2000      4      British Grand Prix  silverstone
# 4      2000      5      Spanish Grand Prix    catalunya
# ..      ...    ...                     ...          ...
# 520    2026     18  Mexico City Grand Prix    rodriguez
# 521    2026     19    Brazilian Grand Prix   interlagos
# 522    2026     20    Las Vegas Grand Prix        vegas
# 523    2026     21        Qatar Grand Prix       losail
# 524    2026     22    Abu Dhabi Grand Prix   yas_marina
#
#                        circuit_name    country     locality        date  \
# 0    Albert Park Grand Prix Circuit  Australia    Melbourne  2000-03-12
# 1        Autódromo José Carlos Pace     Brazil    São Paulo  2000-03-26
# 2     Autodromo Enzo e Dino Ferrari      Italy        Imola  2000-04-09
# ...

# %%
print(races.columns.tolist())
# Out:
# ['season', 'round', 'race_name', 'circuit_id', 'circuit_name', 'country', 'locality', 'date', 'race_url']

# %%
import pandas as pd

results = pd.read_csv("f1_race_results_2000_2026.csv")

print(results.columns.tolist())
print(results.shape)
# Out:
# ['season', 'round', 'race_name', 'date', 'driver_id', 'driver_name', 'nationality', 'constructor', 'constructor_id', 'grid', 'position', 'position_text', 'points', 'laps', 'status', 'fastest_lap_rank', 'fastest_lap_time', 'fastest_lap_speed']
# (2666, 18)

# %%
qualifying = pd.read_csv("f1_qualifying_2000_2026.csv")

print(qualifying.columns.tolist())
print(qualifying.shape)
# Out:
# ['season', 'round', 'race_name', 'date', 'driver_id', 'driver_name', 'constructor', 'position', 'q1_time', 'q2_time', 'q3_time']
# (2515, 11)

# %%
driver_standings = pd.read_csv("f1_driver_standings_2000_2026.csv")

print(driver_standings.columns.tolist())
print(driver_standings.shape)
# Out:
# ['season', 'driver_id', 'driver_name', 'nationality', 'constructor', 'position', 'points', 'wins']
# (370, 8)

# %%
constructor_standings = pd.read_csv("f1_constructor_standings_2000_2026.csv")

print(constructor_standings.columns.tolist())
print(constructor_standings.shape)
# Out:
# ['season', 'constructor_id', 'constructor', 'nationality', 'position', 'points', 'wins']
# (52, 7)
